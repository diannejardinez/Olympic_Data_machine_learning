# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# reading csv file
athlete_events = pd.read_csv('../CSV for ML models/athlete_events.csv')

# %%
athlete_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
filter_data = athlete_events[["Sex", "Age", "Height", "Weight", "Team", "Year", "Season", "Sport", "Event", "Medal"]]

# %%
# get the data for summer and winter Olympic
winter_data = filter_data[filter_data["Season"] == "Winter"]
summer_data = filter_data[(filter_data["Season"] == "Summer")]

# %%
summer_sports = summer_data["Sport"].unique()

# %%
# For loop to train the Random Forest model and get the testing score for male athletes in every Summer Olympic Sport
for sport in summer_sports:
    try:
        athlete_m  = summer_data[(summer_data["Sport"] == f'{sport}') & (summer_data["Sex"] == "M")]
        athlete_m  = athlete_m [["Age", "Height", "Weight", "Medal"]]
        athlete_m  = athlete_m .dropna(subset=['Height', 'Weight']).reset_index(drop = True)
        
        # One-hot encoding                

        athlete_m  = athlete_m .replace("Gold", 1)
        athlete_m  = athlete_m .replace("Silver", 1)
        athlete_m  = athlete_m .replace("Bronze", 1)
        athlete_m ["Medal"] = athlete_m ["Medal"].fillna(0)
        athlete_m  = athlete_m .dropna()
        athlete_m ["Medal"].unique()

        print(sport)
        
        # Assign X (data) and y (target)        

        target = athlete_m ["Medal"]
        target_names = ["Medals", "None"]
        data = athlete_m .drop("Medal", axis=1)
        feature_names = data.columns
        data.head()
        
        # Split our data into training and testing

        X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
        clf = tree.DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        clf.score(X_test, y_test)
        
        # Create a random forest classifier

        rf = RandomForestClassifier(n_estimators=200)
        rf = rf.fit(X_train, y_train)
        print("Training Data Score:", rf.score(X_train, y_train)) 
        print("Testing Data Score:", rf.score(X_test, y_test))
        
        # Sort the features by their importance

        print(sorted(zip(rf.feature_importances_, feature_names), reverse=True))
        print("----------------------------------------------------")
    except:
        print("An exception occurred")
        print("----------------------------------------------------")
# Out:
# Basketball
# Training Data Score: 0.9723577235772358
# Testing Data Score: 0.6834415584415584
# [(0.42143922527920546, 'Weight'), (0.35490832742816325, 'Height'), (0.22365244729263128, 'Age')]
# ----------------------------------------------------
# Judo
# Training Data Score: 0.9588963963963963
# Testing Data Score: 0.8195615514333895
# [(0.39519015913769856, 'Weight'), (0.3728713953486695, 'Height'), (0.231938445513632, 'Age')]
# ----------------------------------------------------
# Football
# Training Data Score: 0.9175019275250579
# Testing Data Score: 0.7017341040462428
# [(0.38671842766921266, 'Weight'), (0.38104477372215234, 'Height'), (0.23223679860863491, 'Age')]
# ----------------------------------------------------
# Tug-Of-War
# Training Data Score: 1.0
# Testing Data Score: 0.4
# [(0.4575656434064171, 'Weight'), (0.27764178612943496, 'Height'), (0.2647925704641479, 'Age')]
# ----------------------------------------------------
# Athletics
# Training Data Score: 0.9291903010658854
# Testing Data Score: 0.8582647718773373
# [(0.4236431617680286, 'Weight'), (0.3235982480777706, 'Height'), (0.25275859015420094, 'Age')]
# ----------------------------------------------------
# Swimming
# Training Data Score: 0.9191214470284238
# Testing Data Score: 0.8636187524215421
# [(0.4105058760297427, 'Weight'), (0.34389205743409523, 'Height'), (0.24560206653616196, 'Age')]
# ----------------------------------------------------
# Badminton
# Training Data Score: 0.9771863117870723
# Testing Data Score: 0.8636363636363636
# [(0.3845784501306299, 'Height'), (0.336351704573283, 'Weight'), (0.27906984529608714, 'Age')]
# ----------------------------------------------------
# Sailing
# Training Data Score: 0.9762859051436206
# Testing Data Score: 0.8316633266533067
# [(0.3748518904482442, 'Weight'), (0.3492016045753758, 'Age'), (0.2759465049763801, 'Height')]
# ----------------------------------------------------
# Gymnastics
# Training Data Score: 0.9458987783595113
# Testing Data Score: 0.9345549738219895
# [(0.3727843924043222, 'Age'), (0.31974867801448364, 'Height'), (0.30746692958119415, 'Weight')]
# ----------------------------------------------------
# Art Competitions
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.40527432504466293, 'Height'), (0.3258130271448169, 'Weight'), (0.26891264781052016, 'Age')]
# ----------------------------------------------------
# Handball
# Training Data Score: 0.9633267845448592
# Testing Data Score: 0.6817288801571709
# [(0.38334842894597754, 'Weight'), (0.3279687923947982, 'Height'), (0.2886827786592243, 'Age')]
# ----------------------------------------------------
# Weightlifting
# Training Data Score: 0.9692307692307692
# Testing Data Score: 0.8060413354531002
# [(0.4333895133246143, 'Weight'), (0.34923061480707956, 'Height'), (0.21737987186830618, 'Age')]
# ----------------------------------------------------
# Wrestling
# Training Data Score: 0.9404696886947024
# Testing Data Score: 0.7665847665847666
# [(0.41106731307425937, 'Weight'), (0.34998150117507537, 'Height'), (0.23895118575066526, 'Age')]
# ----------------------------------------------------
# Water Polo
# Training Data Score: 0.9641362821279139
# Testing Data Score: 0.6881720430107527
# [(0.37954382498406447, 'Weight'), (0.3395584707142497, 'Height'), (0.28089770430168587, 'Age')]
# ----------------------------------------------------
# Hockey
# Training Data Score: 0.9419953596287703
# Testing Data Score: 0.674547983310153
# [(0.377993893935953, 'Weight'), (0.3431957534555919, 'Height'), (0.2788103526084551, 'Age')]
# ----------------------------------------------------
# Rowing
# Training Data Score: 0.9138823529411765
# Testing Data Score: 0.6923076923076923
# [(0.38695987541477, 'Weight'), (0.3490374575802553, 'Height'), (0.26400266700497477, 'Age')]
# ----------------------------------------------------
# Fencing
# Training Data Score: 0.9146136618141097
# Testing Data Score: 0.797649034424853
# [(0.3545058483995102, 'Weight'), (0.3315408453910586, 'Age'), (0.31395330620943107, 'Height')]
# ----------------------------------------------------
# Equestrianism
# Training Data Score: 0.9168627450980392
# Testing Data Score: 0.8341176470588235
# [(0.3678483509209346, 'Age'), (0.3185056350730699, 'Weight'), (0.31364601400599557, 'Height')]
# ----------------------------------------------------
# Shooting
# Training Data Score: 0.9745055992375506
# Testing Data Score: 0.90421729807005
# [(0.38303322278486296, 'Weight'), (0.3092168307427834, 'Age'), (0.30774994647235376, 'Height')]
# ----------------------------------------------------
# Boxing
# Training Data Score: 0.9275092936802974
# Testing Data Score: 0.8159851301115242
# [(0.4140588088266395, 'Height'), (0.3538288768820603, 'Weight'), (0.2321123142913002, 'Age')]
# ----------------------------------------------------
# Taekwondo
# Training Data Score: 0.9956331877729258
# Testing Data Score: 0.7532467532467533
# [(0.39959785978696705, 'Height'), (0.3109622642894445, 'Age'), (0.28943987592358844, 'Weight')]
# ----------------------------------------------------
# Cycling
# Training Data Score: 0.9457219805262067
# Testing Data Score: 0.8627329192546583
# [(0.38300566292153915, 'Weight'), (0.32265055258417447, 'Height'), (0.29434378449428644, 'Age')]
# ----------------------------------------------------
# Diving
# Training Data Score: 0.948849104859335
# Testing Data Score: 0.8314176245210728
# [(0.336563513489517, 'Age'), (0.33441080215243796, 'Weight'), (0.32902568435804497, 'Height')]
# ----------------------------------------------------
# Canoeing
# Training Data Score: 0.9344159900062461
# Testing Data Score: 0.7827715355805244
# [(0.355794195186982, 'Weight'), (0.3494377692275653, 'Height'), (0.2947680355854528, 'Age')]
# ----------------------------------------------------
# Tennis
# Training Data Score: 0.9591315453384419
# Testing Data Score: 0.8735632183908046
# [(0.36418288848772784, 'Weight'), (0.3251295452590567, 'Height'), (0.3106875662532156, 'Age')]
# ----------------------------------------------------
# Modern Pentathlon
# Training Data Score: 0.9269183922046285
# Testing Data Score: 0.8759124087591241
# [(0.35539393394872953, 'Weight'), (0.32695706323402346, 'Height'), (0.31764900281724695, 'Age')]
# ----------------------------------------------------
# Golf
# Training Data Score: 1.0
# Testing Data Score: 0.9285714285714286
# [(0.4798218460178934, 'Height'), (0.318683387128411, 'Weight'), (0.2014947668536956, 'Age')]
# ----------------------------------------------------
# Softball
# An exception occurred
# ----------------------------------------------------
# Archery
# Training Data Score: 0.94
# Testing Data Score: 0.856
# [(0.3863597272088662, 'Weight'), (0.3408046624874894, 'Age'), (0.2728356103036445, 'Height')]
# ----------------------------------------------------
# Volleyball
# Training Data Score: 0.9595808383233533
# Testing Data Score: 0.6278026905829597
# [(0.37574648599637994, 'Weight'), (0.362676007723324, 'Height'), (0.26157750628029613, 'Age')]
# ----------------------------------------------------
# Synchronized Swimming
# An exception occurred
# ----------------------------------------------------
# Table Tennis
# Training Data Score: 0.9553956834532374
# Testing Data Score: 0.8879310344827587
# [(0.356759325041711, 'Weight'), (0.3360034517568771, 'Age'), (0.30723722320141184, 'Height')]
# ----------------------------------------------------
# Baseball
# Training Data Score: 0.9716088328075709
# Testing Data Score: 0.5707547169811321
# [(0.3913044492641938, 'Weight'), (0.3325619752654058, 'Height'), (0.27613357547040046, 'Age')]
# ----------------------------------------------------
# Rhythmic Gymnastics
# An exception occurred
# ----------------------------------------------------
# Rugby Sevens
# Training Data Score: 1.0
# Testing Data Score: 0.6842105263157895
# [(0.3950553836561025, 'Height'), (0.35448476880536395, 'Weight'), (0.25045984753853356, 'Age')]
# ----------------------------------------------------
# Trampolining
# Training Data Score: 1.0
# Testing Data Score: 0.7894736842105263
# [(0.4404689154087123, 'Weight'), (0.30267681332348173, 'Age'), (0.2568542712678061, 'Height')]
# ----------------------------------------------------
# Beach Volleyball
# Training Data Score: 0.9950980392156863
# Testing Data Score: 0.9130434782608695
# [(0.3519970292441555, 'Height'), (0.3281783495184385, 'Weight'), (0.3198246212374062, 'Age')]
# ----------------------------------------------------
# Triathlon
# Training Data Score: 1.0
# Testing Data Score: 0.8955223880597015
# [(0.3819409447193126, 'Height'), (0.3273875824048605, 'Age'), (0.29067147287582695, 'Weight')]
# ----------------------------------------------------
# Rugby
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Lacrosse
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Polo
# An exception occurred
# ----------------------------------------------------
# Cricket
# An exception occurred
# ----------------------------------------------------
# Ice Hockey
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Racquets
# An exception occurred
# ----------------------------------------------------
# Motorboating
# An exception occurred
# ----------------------------------------------------
# Croquet
# An exception occurred
# ----------------------------------------------------
# Figure Skating
# An exception occurred
# ----------------------------------------------------
# Jeu De Paume
# An exception occurred
# ----------------------------------------------------
# Roque
# An exception occurred
# ----------------------------------------------------
# Basque Pelota
# An exception occurred
# ----------------------------------------------------
# Alpinism
# An exception occurred
# ----------------------------------------------------
# Aeronautics
# An exception occurred
# ----------------------------------------------------

# %%
# For loop to train the Random Forest model and get the testing score for female athletes in every Summer Olympic Sport
for sport in summer_sports:
    try:
        athlete_f  = summer_data[(summer_data["Sport"] == f'{sport}') & (summer_data["Sex"] == "M")]
        athlete_f  = athlete_f [["Age", "Height", "Weight", "Medal"]]
        athlete_f  = athlete_f .dropna(subset=['Height', 'Weight']).reset_index(drop = True)
        
        # One-hot encoding                

        athlete_f  = athlete_f .replace("Gold", 1)
        athlete_f  = athlete_f .replace("Silver", 1)
        athlete_f  = athlete_f .replace("Bronze", 1)
        athlete_f ["Medal"] = athlete_f ["Medal"].fillna(0)
        athlete_f  = athlete_f .dropna()
        athlete_f ["Medal"].unique()

        print(sport)
        
        # Assign X (data) and y (target)        

        target = athlete_f ["Medal"]
        target_names = ["Medals", "None"]
        data = athlete_f .drop("Medal", axis=1)
        feature_names = data.columns
        data.head()
        
        # Split our data into training and testing

        X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
        clf = tree.DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        clf.score(X_test, y_test)
        
        # Create a random forest classifier

        rf = RandomForestClassifier(n_estimators=200)
        rf = rf.fit(X_train, y_train)
        print("Training Data Score:", rf.score(X_train, y_train)) 
        print("Testing Data Score:", rf.score(X_test, y_test))
        
        # Sort the features by their importance
        
        print(sorted(zip(rf.feature_importances_, feature_names), reverse=True))
        print("----------------------------------------------------")
    except:
        print("An exception occurred")
        print("----------------------------------------------------")
# Out:
# Basketball
# Training Data Score: 0.9723577235772358
# Testing Data Score: 0.6818181818181818
# [(0.41693851358630973, 'Weight'), (0.3484694346600359, 'Height'), (0.2345920517536544, 'Age')]
# ----------------------------------------------------
# Judo
# Training Data Score: 0.9588963963963963
# Testing Data Score: 0.821247892074199
# [(0.3885768787864628, 'Weight'), (0.3671280355203363, 'Height'), (0.24429508569320102, 'Age')]
# ----------------------------------------------------
# Football
# Training Data Score: 0.9175019275250579
# Testing Data Score: 0.7109826589595376
# [(0.3883071169269278, 'Height'), (0.37367025314955526, 'Weight'), (0.23802262992351697, 'Age')]
# ----------------------------------------------------
# Tug-Of-War
# Training Data Score: 1.0
# Testing Data Score: 0.4
# [(0.48102521243637325, 'Weight'), (0.2776424642321963, 'Age'), (0.24133232333143045, 'Height')]
# ----------------------------------------------------
# Athletics
# Training Data Score: 0.9291903010658854
# Testing Data Score: 0.8578908002991773
# [(0.42871779650265257, 'Weight'), (0.3226573693955822, 'Height'), (0.24862483410176514, 'Age')]
# ----------------------------------------------------
# Swimming
# Training Data Score: 0.9191214470284238
# Testing Data Score: 0.8647810925997675
# [(0.40755381580288647, 'Weight'), (0.3505249637496847, 'Height'), (0.24192122044742884, 'Age')]
# ----------------------------------------------------
# Badminton
# Training Data Score: 0.9771863117870723
# Testing Data Score: 0.8522727272727273
# [(0.3952902019393844, 'Height'), (0.3328750367258375, 'Weight'), (0.2718347613347781, 'Age')]
# ----------------------------------------------------
# Sailing
# Training Data Score: 0.9762859051436206
# Testing Data Score: 0.8286573146292585
# [(0.375200787928225, 'Weight'), (0.35252071359597675, 'Age'), (0.2722784984757983, 'Height')]
# ----------------------------------------------------
# Gymnastics
# Training Data Score: 0.9458987783595113
# Testing Data Score: 0.9360508601346298
# [(0.35650164287024994, 'Age'), (0.33156092871357834, 'Height'), (0.3119374284161718, 'Weight')]
# ----------------------------------------------------
# Art Competitions
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.3718273332380388, 'Height'), (0.3140940234901274, 'Age'), (0.3140786432718339, 'Weight')]
# ----------------------------------------------------
# Handball
# Training Data Score: 0.9633267845448592
# Testing Data Score: 0.6777996070726916
# [(0.383557183883512, 'Weight'), (0.33374430317306547, 'Height'), (0.28269851294342263, 'Age')]
# ----------------------------------------------------
# Weightlifting
# Training Data Score: 0.9692307692307692
# Testing Data Score: 0.7980922098569158
# [(0.4340255891359887, 'Weight'), (0.35060033502166815, 'Height'), (0.2153740758423431, 'Age')]
# ----------------------------------------------------
# Wrestling
# Training Data Score: 0.9404696886947024
# Testing Data Score: 0.7682227682227682
# [(0.4045668293198677, 'Weight'), (0.3454995131388042, 'Height'), (0.24993365754132807, 'Age')]
# ----------------------------------------------------
# Water Polo
# Training Data Score: 0.9641362821279139
# Testing Data Score: 0.6827956989247311
# [(0.3723251801769605, 'Weight'), (0.33365422211580265, 'Height'), (0.2940205977072368, 'Age')]
# ----------------------------------------------------
# Hockey
# Training Data Score: 0.9419953596287703
# Testing Data Score: 0.6689847009735744
# [(0.3718003607419815, 'Weight'), (0.3489415280529149, 'Height'), (0.27925811120510374, 'Age')]
# ----------------------------------------------------
# Rowing
# Training Data Score: 0.9138823529411765
# Testing Data Score: 0.7021877205363444
# [(0.38114456434559807, 'Weight'), (0.34848156646366035, 'Height'), (0.2703738691907416, 'Age')]
# ----------------------------------------------------
# Fencing
# Training Data Score: 0.9146136618141097
# Testing Data Score: 0.7984886649874056
# [(0.3501631798272655, 'Weight'), (0.3292793523597575, 'Height'), (0.32055746781297684, 'Age')]
# ----------------------------------------------------
# Equestrianism
# Training Data Score: 0.9168627450980392
# Testing Data Score: 0.8364705882352941
# [(0.3739754727605139, 'Age'), (0.32267257067803956, 'Weight'), (0.3033519565614465, 'Height')]
# ----------------------------------------------------
# Shooting
# Training Data Score: 0.9745055992375506
# Testing Data Score: 0.9035025017869907
# [(0.3789804648147096, 'Weight'), (0.32121219345331853, 'Height'), (0.29980734173197193, 'Age')]
# ----------------------------------------------------
# Boxing
# Training Data Score: 0.9275092936802974
# Testing Data Score: 0.8094795539033457
# [(0.41500771458929625, 'Height'), (0.3558090011843699, 'Weight'), (0.2291832842263338, 'Age')]
# ----------------------------------------------------
# Taekwondo
# Training Data Score: 0.9956331877729258
# Testing Data Score: 0.7402597402597403
# [(0.3862244706884465, 'Height'), (0.3221581131960231, 'Age'), (0.29161741611553044, 'Weight')]
# ----------------------------------------------------
# Cycling
# Training Data Score: 0.9457219805262067
# Testing Data Score: 0.8614906832298137
# [(0.3579034436385548, 'Weight'), (0.34643070587872754, 'Height'), (0.29566585048271776, 'Age')]
# ----------------------------------------------------
# Diving
# Training Data Score: 0.948849104859335
# Testing Data Score: 0.8314176245210728
# [(0.3427396852515783, 'Weight'), (0.3352124929649689, 'Age'), (0.3220478217834529, 'Height')]
# ----------------------------------------------------
# Canoeing
# Training Data Score: 0.9344159900062461
# Testing Data Score: 0.7808988764044944
# [(0.36132707282643944, 'Weight'), (0.3481452359194355, 'Height'), (0.29052769125412503, 'Age')]
# ----------------------------------------------------
# Tennis
# Training Data Score: 0.9591315453384419
# Testing Data Score: 0.8735632183908046
# [(0.3468373400156811, 'Weight'), (0.3427689801108659, 'Age'), (0.310393679873453, 'Height')]
# ----------------------------------------------------
# Modern Pentathlon
# Training Data Score: 0.9269183922046285
# Testing Data Score: 0.8722627737226277
# [(0.3687783600714731, 'Weight'), (0.31692075037081424, 'Age'), (0.3143008895577126, 'Height')]
# ----------------------------------------------------
# Golf
# Training Data Score: 1.0
# Testing Data Score: 0.9285714285714286
# [(0.49254975615219987, 'Height'), (0.28803776735355696, 'Weight'), (0.2194124764942432, 'Age')]
# ----------------------------------------------------
# Softball
# An exception occurred
# ----------------------------------------------------
# Archery
# Training Data Score: 0.94
# Testing Data Score: 0.856
# [(0.3856748430822299, 'Weight'), (0.34785645935076426, 'Age'), (0.26646869756700586, 'Height')]
# ----------------------------------------------------
# Volleyball
# Training Data Score: 0.9595808383233533
# Testing Data Score: 0.6278026905829597
# [(0.36418569901128695, 'Weight'), (0.36264841234994133, 'Height'), (0.2731658886387716, 'Age')]
# ----------------------------------------------------
# Synchronized Swimming
# An exception occurred
# ----------------------------------------------------
# Table Tennis
# Training Data Score: 0.9553956834532374
# Testing Data Score: 0.8879310344827587
# [(0.35037269047118635, 'Weight'), (0.3443096664614272, 'Age'), (0.30531764306738646, 'Height')]
# ----------------------------------------------------
# Baseball
# Training Data Score: 0.9716088328075709
# Testing Data Score: 0.5518867924528302
# [(0.3957751758163793, 'Weight'), (0.3368374007947025, 'Height'), (0.26738742338891824, 'Age')]
# ----------------------------------------------------
# Rhythmic Gymnastics
# An exception occurred
# ----------------------------------------------------
# Rugby Sevens
# Training Data Score: 1.0
# Testing Data Score: 0.7105263157894737
# [(0.40191072845237447, 'Height'), (0.3394004236205719, 'Weight'), (0.2586888479270537, 'Age')]
# ----------------------------------------------------
# Trampolining
# Training Data Score: 1.0
# Testing Data Score: 0.7894736842105263
# [(0.4252726406124823, 'Weight'), (0.30632876222850863, 'Age'), (0.26839859715900916, 'Height')]
# ----------------------------------------------------
# Beach Volleyball
# Training Data Score: 0.9950980392156863
# Testing Data Score: 0.9130434782608695
# [(0.3519094425443224, 'Height'), (0.3264279306161144, 'Weight'), (0.32166262683956326, 'Age')]
# ----------------------------------------------------
# Triathlon
# Training Data Score: 1.0
# Testing Data Score: 0.9104477611940298
# [(0.39656931191610895, 'Height'), (0.3181637458481218, 'Age'), (0.28526694223576937, 'Weight')]
# ----------------------------------------------------
# Rugby
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Lacrosse
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Polo
# An exception occurred
# ----------------------------------------------------
# Cricket
# An exception occurred
# ----------------------------------------------------
# Ice Hockey
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Racquets
# An exception occurred
# ----------------------------------------------------
# Motorboating
# An exception occurred
# ----------------------------------------------------
# Croquet
# An exception occurred
# ----------------------------------------------------
# Figure Skating
# An exception occurred
# ----------------------------------------------------
# Jeu De Paume
# An exception occurred
# ----------------------------------------------------
# Roque
# An exception occurred
# ----------------------------------------------------
# Basque Pelota
# An exception occurred
# ----------------------------------------------------
# Alpinism
# An exception occurred
# ----------------------------------------------------
# Aeronautics
# An exception occurred
# ----------------------------------------------------
