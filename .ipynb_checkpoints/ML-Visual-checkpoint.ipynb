# %%
import pandas as pd

# %%
data = {'Year':  [2004, 2008, 2012, 2016, 2020],
        'Country': ['USA', 'USA', 'USA', 'USA', 'USA' ],
        'Predicted Gold Medals': [99,43,42,44,41],
        'Predicted Silver Medals': [41,33,32,34,29],
        'Predicted Bronze Medals': [30,31,30,32,26],
        'Predicted Total Medals': [28,106,104,110,96],
        'Actual Gold Medals': [36,36,46,46,0],
        'Actual Silver Medals': [39,39,28,37,0],
        'Actual Bronze Medals': [26,35,29,38,0],
        'Actual Total Medals': [101,10,103,121,0],
        'Machine Learning Model': ['Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',]
         
        }

linear_ML_predictions = pd.DataFrame (data, columns = ['Year','Country', 
                                                       'Predicted Gold Medals','Predicted Silver Medals', 'Predicted Bronze Medals','Predicted Total Medals',
                                                       'Actual Gold Medals','Actual Silver Medals', 'Actual Bronze Medals','Actual Total Medals',
                                                       'Machine Learning Model'])

linear_ML_predictions
# Out:
#    Year Country  Predicted Gold Medals  Predicted Silver Medals  \
# 0  2004     USA                     99                       41
# 1  2008     USA                     43                       33
# 2  2012     USA                     42                       32
# 3  2016     USA                     44                       34
# 4  2020     USA                     41                       29
#
#    Predicted Bronze Medals  Predicted Total Medals  Actual Gold Medals  \
# 0                       30                      28                  36
# 1                       31                     106                  36
# 2                       30                     104                  46
# 3                       32                     110                  46
# 4                       26                      96                   0
#
#    Actual Silver Medals  Actual Bronze Medals  Actual Total Medals  \
# 0                    39                    26                  101
# ...

# %%
# Save into a csv file
linear_ML_predictions.to_csv('Resources/linear.csv', index=False)

# %% [markdown]
# # Total Medals

# %%
data = {'Year':  [
                2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,
                 2016,2016,2016,2016,2016,2016,2016,2016,2016,2016],
        'Country': ['USA',
                    'Russia',
                    'Germany',
                    'UK',
                    'France',
                    'Italy',
                    'China',
                    'Australia',
                    'Sweden',
                    'Hungary',
                    'Japan',
                    'Finland',
                    'Canada',
                    'Romania',
                    'Netherlands',
                    'Poland',
                    'South Korea',
                    'Bulgaria',
                    'Cuba',
                    'Denmark',
                    'Switzerland',
                    'Czech Republic',
                    'Belgium',
                    'Norway',
                    'Greece'],
#         'Predicted Gold Medals': [99,43,42,44,41],
#         'Predicted Silver Medals': [41,33,32,34,29],
#         'Predicted Bronze Medals': [30,31,30,32,26],
        'Predicted Total Medals': [
                                    108,
                                    65,
                                    59,
                                    37,
                                    41,
                                    31,
                                    56,
                                    44,
                                    12,
                                    14,
                                    33,
                                    4,
                                    21,
                                    11,
                                    19,
                                    19,
                                    16,
                                    2,
                                    6,
                                    8,
                                    4,
                                    0,
                                    2,
                                    2,
                                    1],
#         'Actual Gold Medals': [36,36,46,46,0],
#         'Actual Silver Medals': [39,39,28,37,0],
#         'Actual Bronze Medals': [26,35,29,38,0],
        'Actual Total Medals': [
                            121,
                            56,
                            42,
                            67,
                            42,
                            28,
                            70,
                            29,
                            11,
                            15,
                            41,
                            1,
                            22,
                            4,
                            19,
                            11,
                            21,
                            3,
                            11,
                            15,
                            7,
                            10,
                            6,
                            4,
                            6,
        ],
        'Machine Learning Model': ['Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',]
         
        }

top25_linear_ML_predictions = pd.DataFrame (data, columns = ['Year','Country', 
                                                       'Predicted Total Medals',
                                                    'Actual Total Medals',
                                                       'Machine Learning Model'])

top25_linear_ML_predictions
# Out:
#     Year         Country  Predicted Total Medals  Actual Total Medals  \
# 0   2016             USA                     108                  121
# 1   2016          Russia                      65                   56
# 2   2016         Germany                      59                   42
# 3   2016              UK                      37                   67
# 4   2016          France                      41                   42
# 5   2016           Italy                      31                   28
# 6   2016           China                      56                   70
# 7   2016       Australia                      44                   29
# 8   2016          Sweden                      12                   11
# 9   2016         Hungary                      14                   15
# 10  2016           Japan                      33                   41
# 11  2016         Finland                       4                    1
# ...

# %%
# Save into a csv file
top25_linear_ML_predictions.to_csv('Resources/top25_linear.csv', index=False)

# %% [markdown]
# # Gold Medals

# %%
data = {'Year':  [
                2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,
                 2016,2016,2016,2016,2016,2016,2016,2016,2016,2016],
        'Country': ['USA',
                    'Russia',
                    'Germany',
                    'UK',
                    'France',
                    'Italy',
                    'China',
                    'Australia',
                    'Sweden',
                    'Hungary',
                    'Japan',
                    'Finland',
                    'Canada',
                    'Romania',
                    'Netherlands',
                    'Poland',
                    'South Korea',
                    'Bulgaria',
                    'Cuba',
                    'Denmark',
                    'Switzerland',
                    'Czech Republic',
                    'Belgium',
                    'Norway',
                    'Greece'],
#         'Predicted Gold Medals': [99,43,42,44,41],
#         'Predicted Silver Medals': [41,33,32,34,29],
#         'Predicted Bronze Medals': [30,31,30,32,26],
        'Predicted Total Medals': [
                                    108,
                                    65,
                                    59,
                                    37,
                                    41,
                                    31,
                                    56,
                                    44,
                                    12,
                                    14,
                                    33,
                                    4,
                                    21,
                                    11,
                                    19,
                                    19,
                                    16,
                                    2,
                                    6,
                                    8,
                                    4,
                                    0,
                                    2,
                                    2,
                                    1],
#         'Actual Gold Medals': [36,36,46,46,0],
#         'Actual Silver Medals': [39,39,28,37,0],
#         'Actual Bronze Medals': [26,35,29,38,0],
        'Actual Total Medals': [
                            121,
                            56,
                            42,
                            67,
                            42,
                            28,
                            70,
                            29,
                            11,
                            15,
                            41,
                            1,
                            22,
                            4,
                            19,
                            11,
                            21,
                            3,
                            11,
                            15,
                            7,
                            10,
                            6,
                            4,
                            6,
        ],
        'Machine Learning Model': ['Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',
                                  'Linear Regression', 'Linear Regression','Linear Regression','Linear Regression','Linear Regression',]
         
        }

gold_top25_linear_ML_predictions = pd.DataFrame (data, columns = ['Year','Country', 
                                                       'Predicted Total Medals',
                                                    'Actual Total Medals',
                                                       'Machine Learning Model'])

gold_top25_linear_ML_predictions
# Out:
#     Year         Country  Predicted Total Medals  Actual Total Medals  \
# 0   2016             USA                     108                  121
# 1   2016          Russia                      65                   56
# 2   2016         Germany                      59                   42
# 3   2016              UK                      37                   67
# 4   2016          France                      41                   42
# 5   2016           Italy                      31                   28
# 6   2016           China                      56                   70
# 7   2016       Australia                      44                   29
# 8   2016          Sweden                      12                   11
# 9   2016         Hungary                      14                   15
# 10  2016           Japan                      33                   41
# 11  2016         Finland                       4                    1
# ...

# %%
# Save into a csv file
gold_top25_linear_ML_predictions.to_csv('Resources/gold_top25_linear.csv', index=False)

# %%
data = {'Year':  [2004, 2008, 2012, 2016, 2020],
        'Country': ['USA', 'USA', 'USA', 'USA', 'USA', ],
        'Predicted Gold Medals': [39,41,36,38,41],
        'Predicted Silver Medals': [31,32,30,37,37],
        'Predicted Bronze Medals': [29,29,32,32,35],
        'Predicted Total Medals': [99,100,110,110,117],
        'Actual Gold Medals': [36,36,46,46,0],
        'Actual Silver Medals': [39,39,28,37,0],
        'Actual Bronze Medals': [26,35,29,38,0],
        'Actual Total Medals': [101,10,103,121,0],
        'Machine Learning Model': ['ARIMA Model', 'ARIMA Model','ARIMA Model','ARIMA Model','ARIMA Model']
         
        }

arima_ML_predictions = pd.DataFrame (data, columns = ['Year','Country', 
                                                       'Predicted Gold Medals','Predicted Silver Medals', 'Predicted Bronze Medals','Predicted Total Medals',
                                                       'Actual Gold Medals','Actual Silver Medals', 'Actual Bronze Medals','Actual Total Medals',
                                                      'Machine Learning Model'])

arima_ML_predictions
# Out:
#    Year Country  Predicted Gold Medals  Predicted Silver Medals  \
# 0  2004     USA                     39                       31
# 1  2008     USA                     41                       32
# 2  2012     USA                     36                       30
# 3  2016     USA                     38                       37
# 4  2020     USA                     41                       37
#
#    Predicted Bronze Medals  Predicted Total Medals  Actual Gold Medals  \
# 0                       29                      99                  36
# 1                       29                     100                  36
# 2                       32                     110                  46
# 3                       32                     110                  46
# 4                       35                     117                   0
#
#    Actual Silver Medals  Actual Bronze Medals  Actual Total Medals  \
# 0                    39                    26                  101
# ...

# %%
# Save into a csv file
arima_ML_predictions.to_csv('Resources/arima.csv', index=False)
