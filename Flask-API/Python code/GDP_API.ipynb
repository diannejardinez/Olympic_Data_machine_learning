# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url = "https://pkgstore.datahub.io/core/gdp/gdp_json/data/1a2503aa36368933be8f9a96e1dc16de/gdp_json.json"

# %%
response = requests.get(url).json()
response[0]
# Out:
# {'Country Code': 'ARB',
#  'Country Name': 'Arab World',
#  'Value': 25760683041.0857,
#  'Year': 1968}

# %%
columns = ["Country Code", "Country Name", "Value", "Year"]

df = pd.DataFrame(response, columns=columns)
df.head()
# Out:
#   Country Code Country Name         Value  Year
# 0          ARB   Arab World  2.576068e+10  1968
# 1          ARB   Arab World  2.843420e+10  1969
# 2          ARB   Arab World  3.138550e+10  1970
# 3          ARB   Arab World  3.642691e+10  1971
# 4          ARB   Arab World  4.331606e+10  1972

# %%
df["Country Name"].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
df1 = df.set_index("Country Name")
df1
# Out:
#              Country Code         Value  Year
# Country Name
# Arab World            ARB  2.576068e+10  1968
# Arab World            ARB  2.843420e+10  1969
# Arab World            ARB  3.138550e+10  1970
# Arab World            ARB  3.642691e+10  1971
# Arab World            ARB  4.331606e+10  1972
# ...                   ...           ...   ...
# Zimbabwe              ZWE  1.424249e+10  2012
# Zimbabwe              ZWE  1.545177e+10  2013
# Zimbabwe              ZWE  1.589105e+10  2014
# Zimbabwe              ZWE  1.630467e+10  2015
# Zimbabwe              ZWE  1.661996e+10  2016
#
# [11507 rows x 3 columns]

# %%
df1.drop(index = "Arab World")
# Out:
#                        Country Code         Value  Year
# Country Name
# Caribbean small states          CSS  2.004785e+09  1960
# Caribbean small states          CSS  2.169733e+09  1961
# Caribbean small states          CSS  2.289495e+09  1962
# Caribbean small states          CSS  2.431592e+09  1963
# Caribbean small states          CSS  2.626896e+09  1964
# ...                             ...           ...   ...
# Zimbabwe                        ZWE  1.424249e+10  2012
# Zimbabwe                        ZWE  1.545177e+10  2013
# Zimbabwe                        ZWE  1.589105e+10  2014
# Zimbabwe                        ZWE  1.630467e+10  2015
# Zimbabwe                        ZWE  1.661996e+10  2016
#
# [11458 rows x 3 columns]

# %%
data = df1.drop(["Arab World", 'Caribbean small states', 'Central Europe and the Baltics', 'Early-demographic dividend', 'East Asia & Pacific', 'East Asia & Pacific (excluding high income)', 'East Asia & Pacific (IDA & IBRD countries)', 'Euro area', 'Europe & Central Asia', 'Europe & Central Asia (excluding high income)', 'Europe & Central Asia (IDA & IBRD countries)', 'European Union', 'Fragile and conflict affected situations', 'Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total', 'Late-demographic dividend', 'Latin America & Caribbean', 'Latin America & Caribbean (excluding high income)', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Least developed countries: UN classification', 'Low & middle income', 'Low income', 'Lower middle income', 'Middle East & North Africa', 'Middle East & North Africa (excluding high income)', 'Middle East & North Africa (IDA & IBRD countries)', 'Middle income', 'North America', 'OECD members', 'Other small states', 'Pacific island small states', 'Post-demographic dividend', 'Pre-demographic dividend', 'Small states', 'South Asia', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income', 'World'])

# %%
data
# Out:
#              Country Code         Value  Year
# Country Name
# Afghanistan           AFG  5.377778e+08  1960
# Afghanistan           AFG  5.488889e+08  1961
# Afghanistan           AFG  5.466667e+08  1962
# Afghanistan           AFG  7.511112e+08  1963
# Afghanistan           AFG  8.000000e+08  1964
# ...                   ...           ...   ...
# Zimbabwe              ZWE  1.424249e+10  2012
# Zimbabwe              ZWE  1.545177e+10  2013
# Zimbabwe              ZWE  1.589105e+10  2014
# Zimbabwe              ZWE  1.630467e+10  2015
# Zimbabwe              ZWE  1.661996e+10  2016
#
# [9201 rows x 3 columns]

# %%
data = data.reset_index()

# %%
#data.to_csv("GDP_by_country.csv", index = False)
