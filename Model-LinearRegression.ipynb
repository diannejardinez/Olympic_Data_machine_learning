# %% [markdown]
# Note: Machine Learning - Linear Regression - Currently Training for 1988 Medal Count

# %%
import pandas as pd

# %% [markdown]
# # Data Pre-Processing

# %%
# Load training data
train_data = pd.read_csv("Resources/train.csv")
train_data
# Out:
#     Year Country  Total_Medals  Gold  Silver  Bronze  Athletes  Event  Sport  \
# 0   1896     USA            19    11       6       2        14     16      3
# 1   1900     USA            54    21      16      17        75     41     10
# 2   1904     USA           230    76      79      75       524     95     18
# 3   1906     USA            23    12       5       6        38     28      5
# 4   1908     USA            46    22      12      12       122     52     10
# 5   1912     USA            63    26      18      19       174     68     11
# 6   1920     USA            95    41      27      27       288    113     18
# 7   1924     USA            99    45      27      27       299    108     18
# 8   1928     USA            56    22      18      16       280     96     15
# 9   1932     USA           110    44      36      30       474    122     17
# 10  1936     USA            57    24      21      12       359    127     21
# ...

# %%
# Load testing data
test_data = pd.read_csv("Resources/test.csv")

test_data
# Out:
#    Year Country  Gold  Silver  Bronze  Athletes  Event  Sport  Host
# 0  1988     USA  36.0    31.0    27.0       527    230     27     0
# 1  1992     USA  37.0    34.0    37.0       545    248     28     0
# 2  1996     USA  44.0    32.0    25.0       648    263     31     1
# 3  2000     USA  36.0    24.0    31.0       586    265     31     0
# 4  2004     USA  36.0    39.0    26.0       533    254     31     0
# 5  2008     USA  36.0    39.0    35.0       588    258     32     0
# 6  2012     USA  46.0    28.0    29.0       529    245     31     0
# 7  2016     USA  46.0    37.0    38.0       555    245     33     0
# 8  2020     USA   NaN     NaN     NaN         0      0      0     0

# %%
train_data = pd.DataFrame(train_data)
train_data.describe().columns
# Out:
# Index(['Year', 'Total_Medals', 'Gold', 'Silver', 'Bronze', 'Athletes', 'Event',
#        'Sport', 'Host'],
#       dtype='object')

# %%
# Assign X and y for test and training data
y_train = train_data["Total_Medals"]
X_train_features = train_data[["Year", "Athletes", "Event","Sport","Host"]]
X_train = X_train_features.values


X_test_features = test_data[["Year", "Athletes", "Event","Sport","Host"]]
X_test = X_test_features.values

# %% [markdown]
# # Create and Train(Fit) Model

# %%
 # Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
# Out:
# Training Data Score: 0.8290479327206802

# %% [markdown]
# # Hyperparameter Tuning - Ordinary Least Square

# %%
# Source LInk: https://www.knowledgehut.com/blog/data-science/linear-regression-for-machine-learning

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %% [markdown]
# # Make Predictions

# %%
# Make predictions with model
predictions = model.predict(X_test)

# %%
# Predicting - currently looking at 1988 only - displaying all years for prepping future predictions

output = pd.DataFrame({'Year': test_data.Year, 'Total_Medals': predictions})
output
# Out:
#    Year  Total_Medals
# 0  1988    128.197370
# 1  1992    142.157358
# 2  1996    205.105588
# 3  2000    147.775964
# 4  2004    121.675654
# 5  2008    124.026568
# 6  2012     96.205028
# 7  2016     89.352929
# 8  2020   -220.352862

# %% [markdown]
# Note: Without GridSearchCV
#
#
# Actual medal count for 1988: 94,
# Error: 34
