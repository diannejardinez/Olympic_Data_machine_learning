# %% [markdown]
# ## Preprocess Data to perform Liner Regression
# ---

# %%
import pandas as pd

# %%
olympics_data = pd.read_csv('olympics_data.csv')
print(olympics_data.shape)
olympics_data.head()
# Out:
# (271116, 16)
#    sno  ID                      Name Sex   Age  Height  Weight      Country  \
# 0    0   1                 A Dijiang   M  24.0   180.0    80.0        China
# 1    1   2                  A Lamusi   M  23.0   170.0    60.0        China
# 2    2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN      Denmark
# 3    3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN      Denmark
# 4    4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### Summer Olympics Data
# ---

# %%
# Filtering the dataFrame for 'Summer' season
summer_df = olympics_data[olympics_data['Season'] == 'Summer']

print(summer_df.shape)
summer_df.head()
# Out:
# (222552, 16)
#     sno  ID                                Name Sex   Age  Height  Weight  \
# 0     0   1                           A Dijiang   M  24.0   180.0    80.0
# 1     1   2                            A Lamusi   M  23.0   170.0    60.0
# 2     2   3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3     3   4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#         Country  NOC        Games  Year  Season         City       Sport  \
# 0         China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1         China  CHN  2012 Summer  2012  Summer       London        Judo
# 2       Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3       Denmark  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal
# 0    Basketball Men's Basketball   NaN
# 1   Judo Men's Extra-Lightweight   NaN
# 2        Football Men's Football   NaN
# 3    Tug-Of-War Men's Tug-Of-War  Gold
# 26  Athletics Women's 100 metres   NaN

# %% [markdown]
# ### Host Country Data
# ---

# %% [raw]
# url = 'https://en.wikipedia.org/wiki/List_of_Olympic_Games_host_cities'
#
# host_country_df = pd.read_html(url, index_col = None)[2]
#
# host_country_df = host_country_df[['Country','Year']]
#
# host_country_df = host_country_df.rename(columns = {'Country': 'Host'})
#
# host_country_df = host_country_df.iloc[0:56, :]
#
# host_country_df

# %%
host_df = pd.read_csv('summer_host_country.csv')
host_df
# Out:
#     Year Host_Country
# 0   1896       Greece
# 1   1900       France
# 2   1904          USA
# 3   1906       Greece
# 4   1908           UK
# 5   1912       Sweden
# 6   1920      Belgium
# 7   1924       France
# 8   1928  Netherlands
# 9   1932          USA
# 10  1936      Germany
# 11  1948           UK
# 12  1952      Finland
# 13  1956    Australia
# 14  1960        Italy
# 15  1964        Japan
# 16  1968       Mexico
# 17  1972      Germany
# 18  1976       Canada
# 19  1980       Russia
# 20  1984          USA
# 21  1988  South Korea
# 22  1992        Spain
# 23  1996          USA
# 24  2000    Australia
# 25  2004       Greece
# 26  2008        China
# 27  2012           UK
# 28  2016       Brazil

# %% [markdown]
# ### Merge summer_df and host_df
# ---

# %%
olympicData = pd.merge(summer_df, host_df, how = 'left', on = 'Year')
print(olympicData.shape)
olympicData.head()
# Out:
# (222552, 17)
#    sno  ID                                Name Sex   Age  Height  Weight  \
# 0    0   1                           A Dijiang   M  24.0   180.0    80.0
# 1    1   2                            A Lamusi   M  23.0   170.0    60.0
# 2    2   3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    3   4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4   26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#        Country  NOC        Games  Year  Season         City       Sport  \
# 0        China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1        China  CHN  2012 Summer  2012  Summer       London        Judo
# 2      Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3      Denmark  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal Host_Country
# 0   Basketball Men's Basketball   NaN        Spain
# 1  Judo Men's Extra-Lightweight   NaN           UK
# 2       Football Men's Football   NaN      Belgium
# 3   Tug-Of-War Men's Tug-Of-War  Gold       France
# 4  Athletics Women's 100 metres   NaN          USA

# %% [markdown]
# ### Count of Athletes, Sports and Events
# ---

# %%
athlete_df = olympicData[['Year','Host_Country','NOC','Country','Name','Sport','Event']]

print(athlete_df.shape)
athlete_df.head()
# Out:
# (222552, 7)
#    Year Host_Country  NOC      Country                                Name  \
# 0  1992        Spain  CHN        China                           A Dijiang
# 1  2012           UK  CHN        China                            A Lamusi
# 2  1920      Belgium  DEN      Denmark                 Gunnar Nielsen Aaby
# 3  1900       France  DEN      Denmark                Edgar Lindenau Aabye
# 4  1932          USA  NED  Netherlands  Cornelia "Cor" Aalten (-Strannood)
#
#         Sport                         Event
# 0  Basketball   Basketball Men's Basketball
# 1        Judo  Judo Men's Extra-Lightweight
# 2    Football       Football Men's Football
# 3  Tug-Of-War   Tug-Of-War Men's Tug-Of-War
# 4   Athletics  Athletics Women's 100 metres

# %%
# Sort the dataframe by 'Year'(ascending) and 'Country'(ascending)
athlete_df = athlete_df.sort_values(['Year','Country'],ascending = [True,True])\
                       .reset_index(drop = True)

print(athlete_df.shape)
athlete_df.head(10)
# Out:
# (222552, 7)
#    Year Host_Country  NOC    Country                        Name      Sport  \
# 0  1896       Greece  AUS  Australia  Edwin Harold "Teddy" Flack     Tennis
# 1  1896       Greece  AUS  Australia  Edwin Harold "Teddy" Flack     Tennis
# 2  1896       Greece  AUS  Australia  Edwin Harold "Teddy" Flack  Athletics
# 3  1896       Greece  AUS  Australia  Edwin Harold "Teddy" Flack  Athletics
# 4  1896       Greece  AUS  Australia  Edwin Harold "Teddy" Flack  Athletics
# 5  1896       Greece  AUT    Austria             Otto Herschmann   Swimming
# 6  1896       Greece  AUT    Austria      Paul Neumann (-Newman)   Swimming
# 7  1896       Greece  AUT    Austria      Paul Neumann (-Newman)   Swimming
# 8  1896       Greece  AUT    Austria          Felix Adolf Schmal    Cycling
# 9  1896       Greece  AUT    Austria          Felix Adolf Schmal    Fencing
#
#                                    Event
# 0                   Tennis Men's Singles
# 1                   Tennis Men's Doubles
# 2             Athletics Men's 800 metres
# 3           Athletics Men's 1,500 metres
# 4               Athletics Men's Marathon
# 5    Swimming Men's 100 metres Freestyle
# 6    Swimming Men's 500 metres Freestyle
# 7  Swimming Men's 1,200 metres Freestyle
# 8    Cycling Men's 333 metres Time Trial
# 9        Fencing Men's Sabre, Individual

# %%
athlete_df = athlete_df.groupby(['Year','Host_Country','Country','NOC'])[['Name','Sport','Event']]\
                        .nunique()\
                        .reset_index()

print(athlete_df.shape)
athlete_df.head(10)
# Out:
# (2810, 7)
#    Year Host_Country      Country  NOC  Name  Sport  Event
# 0  1896       Greece    Australia  AUS     1      2      5
# 1  1896       Greece      Austria  AUT     3      3      8
# 2  1896       Greece      Denmark  DEN     3      5     12
# 3  1896       Greece       France  FRA    12      6     18
# 4  1896       Greece      Germany  GER    19      6     27
# 5  1896       Greece       Greece  GRE   102      9     39
# 6  1896       Greece      Hungary  HUN     7      6     14
# 7  1896       Greece        Italy  ITA     1      1      1
# 8  1896       Greece       Sweden  SWE     1      2      5
# 9  1896       Greece  Switzerland  SUI     3      2      5

# %%
athlete_df = athlete_df.rename(columns={'Name':'Athletes', 'Sport':'Sports', 'Event':'Events'})\
                        .reset_index(drop = True)
print(athlete_df.shape)
athlete_df.head(10)
# Out:
# (2810, 7)
#    Year Host_Country      Country  NOC  Athletes  Sports  Events
# 0  1896       Greece    Australia  AUS         1       2       5
# 1  1896       Greece      Austria  AUT         3       3       8
# 2  1896       Greece      Denmark  DEN         3       5      12
# 3  1896       Greece       France  FRA        12       6      18
# 4  1896       Greece      Germany  GER        19       6      27
# 5  1896       Greece       Greece  GRE       102       9      39
# 6  1896       Greece      Hungary  HUN         7       6      14
# 7  1896       Greece        Italy  ITA         1       1       1
# 8  1896       Greece       Sweden  SWE         1       2       5
# 9  1896       Greece  Switzerland  SUI         3       2       5

# %%
# Sort the dataframe by 'Year'(ascending) and 'Athlete Count'(descending)
athlete_df = athlete_df.sort_values(['Year','Athletes'],ascending = [True,False])\
                       .reset_index(drop = True)

print(athlete_df.shape)
athlete_df.head(10)
# Out:
# (2810, 7)
#    Year Host_Country      Country  NOC  Athletes  Sports  Events
# 0  1896       Greece       Greece  GRE       102       9      39
# 1  1896       Greece      Germany  GER        19       6      27
# 2  1896       Greece          USA  USA        14       3      16
# 3  1896       Greece       France  FRA        12       6      18
# 4  1896       Greece           UK  GBR        10       7      19
# 5  1896       Greece      Hungary  HUN         7       6      14
# 6  1896       Greece      Austria  AUT         3       3       8
# 7  1896       Greece      Denmark  DEN         3       5      12
# 8  1896       Greece  Switzerland  SUI         3       2       5
# 9  1896       Greece    Australia  AUS         1       2       5

# %% [raw]
# athlete_df.to_csv('Summer_Athlete_Count.csv',index = False)

# %% [markdown]
# ### Medal Count
# ---

# %%
# Selecting only required columns
medals_df = olympicData[['Year','Host_Country','NOC','Country','Event','Medal']]

# Dropping NaN values in 'Medal' column as we are inerested in only medal count
medals_df = medals_df.dropna()

# Drop duplicate rows for team events.
medals_df = medals_df.drop_duplicates(['Country','Year','Event','Medal'])

medals_df = medals_df.rename(columns={'Medal': 'Medals'})\
                        .reset_index(drop = True)

print(medals_df.shape)
medals_df.head(10)
# Out:
# (16052, 6)
#    Year Host_Country  NOC  Country  \
# 0  1900       France  DEN  Denmark
# 1  1920      Belgium  FIN  Finland
# 2  1920      Belgium  FIN  Finland
# 3  1948           UK  FIN  Finland
# 4  1948           UK  FIN  Finland
# 5  1948           UK  FIN  Finland
# 6  1948           UK  FIN  Finland
# 7  1952      Finland  FIN  Finland
# 8  2008        China  NOR   Norway
# 9  1920      Belgium  NOR   Norway
#
#                                            Event  Medals
# 0                    Tug-Of-War Men's Tug-Of-War    Gold
# 1         Swimming Men's 200 metres Breaststroke  Bronze
# 2         Swimming Men's 400 metres Breaststroke  Bronze
# 3         Gymnastics Men's Individual All-Around  Bronze
# 4               Gymnastics Men's Team All-Around    Gold
# 5                   Gymnastics Men's Horse Vault    Gold
# 6               Gymnastics Men's Pommelled Horse    Gold
# 7               Gymnastics Men's Team All-Around  Bronze
# 8                      Handball Women's Handball    Gold
# 9  Gymnastics Men's Team All-Around, Free System  Silver

# %%
medals_df = medals_df[['Year','Host_Country','NOC','Country','Medals']]\
                .sort_values(['Year','Country'], ascending = [True,True])\
                .reset_index(drop = True)

print(medals_df.shape)
medals_df.head(10)
# Out:
# (16052, 5)
#    Year Host_Country  NOC    Country  Medals
# 0  1896       Greece  AUS  Australia  Bronze
# 1  1896       Greece  AUS  Australia    Gold
# 2  1896       Greece  AUS  Australia    Gold
# 3  1896       Greece  AUT    Austria  Silver
# 4  1896       Greece  AUT    Austria    Gold
# 5  1896       Greece  AUT    Austria  Bronze
# 6  1896       Greece  AUT    Austria  Bronze
# 7  1896       Greece  AUT    Austria    Gold
# 8  1896       Greece  DEN    Denmark  Silver
# 9  1896       Greece  DEN    Denmark    Gold

# %%
medals_df['Gold'] = 0
medals_df['Silver'] = 0
medals_df['Bronze'] = 0

medals_df.loc[medals_df['Medals'] == 'Gold', 'Gold'] = 1
medals_df.loc[medals_df['Medals'] == 'Silver', 'Silver'] = 1
medals_df.loc[medals_df['Medals'] == 'Bronze', 'Bronze'] = 1

print(medals_df.shape)
medals_df.head(10)
# Out:
# (16052, 8)
#    Year Host_Country  NOC    Country  Medals  Gold  Silver  Bronze
# 0  1896       Greece  AUS  Australia  Bronze     0       0       1
# 1  1896       Greece  AUS  Australia    Gold     1       0       0
# 2  1896       Greece  AUS  Australia    Gold     1       0       0
# 3  1896       Greece  AUT    Austria  Silver     0       1       0
# 4  1896       Greece  AUT    Austria    Gold     1       0       0
# 5  1896       Greece  AUT    Austria  Bronze     0       0       1
# 6  1896       Greece  AUT    Austria  Bronze     0       0       1
# 7  1896       Greece  AUT    Austria    Gold     1       0       0
# 8  1896       Greece  DEN    Denmark  Silver     0       1       0
# 9  1896       Greece  DEN    Denmark    Gold     1       0       0

# %%
medals_df = medals_df.drop(['Medals'], axis=1)
print(medals_df.shape)
medals_df.head(10)
# Out:
# (16052, 7)
#    Year Host_Country  NOC    Country  Gold  Silver  Bronze
# 0  1896       Greece  AUS  Australia     0       0       1
# 1  1896       Greece  AUS  Australia     1       0       0
# 2  1896       Greece  AUS  Australia     1       0       0
# 3  1896       Greece  AUT    Austria     0       1       0
# 4  1896       Greece  AUT    Austria     1       0       0
# 5  1896       Greece  AUT    Austria     0       0       1
# 6  1896       Greece  AUT    Austria     0       0       1
# 7  1896       Greece  AUT    Austria     1       0       0
# 8  1896       Greece  DEN    Denmark     0       1       0
# 9  1896       Greece  DEN    Denmark     1       0       0

# %%
# Find total count of medals per year per country
medals_df = medals_df.groupby(['Year','Host_Country','NOC','Country'], sort = False).sum().reset_index()
print(medals_df.shape)
medals_df.head(10)
# Out:
# (1275, 7)
#    Year Host_Country  NOC      Country  Gold  Silver  Bronze
# 0  1896       Greece  AUS    Australia     2       0       1
# 1  1896       Greece  AUT      Austria     2       1       2
# 2  1896       Greece  DEN      Denmark     1       2       3
# 3  1896       Greece  FRA       France     5       4       2
# 4  1896       Greece  GER      Germany     7       5       2
# 5  1896       Greece  GRE       Greece    10      17      17
# 6  1896       Greece  HUN      Hungary     2       1       3
# 7  1896       Greece  SUI  Switzerland     1       2       0
# 8  1896       Greece  GBR           UK     3       3       3
# 9  1896       Greece  USA          USA    11       6       2

# %%
medals_df['Medals'] = medals_df['Gold'] + medals_df['Silver'] + medals_df['Bronze']

print(medals_df.shape)
medals_df.head(10)
# Out:
# (1275, 8)
#    Year Host_Country  NOC      Country  Gold  Silver  Bronze  Medals
# 0  1896       Greece  AUS    Australia     2       0       1       3
# 1  1896       Greece  AUT      Austria     2       1       2       5
# 2  1896       Greece  DEN      Denmark     1       2       3       6
# 3  1896       Greece  FRA       France     5       4       2      11
# 4  1896       Greece  GER      Germany     7       5       2      14
# 5  1896       Greece  GRE       Greece    10      17      17      44
# 6  1896       Greece  HUN      Hungary     2       1       3       6
# 7  1896       Greece  SUI  Switzerland     1       2       0       3
# 8  1896       Greece  GBR           UK     3       3       3       9
# 9  1896       Greece  USA          USA    11       6       2      19

# %%
medals_df = medals_df.sort_values(['Year','Medals','Country'], ascending = [True,False,True])

medals_df = medals_df.reset_index(drop=True)

print(medals_df.shape)
medals_df.head(10)
# Out:
# (1275, 8)
#    Year Host_Country  NOC      Country  Gold  Silver  Bronze  Medals
# 0  1896       Greece  GRE       Greece    10      17      17      44
# 1  1896       Greece  USA          USA    11       6       2      19
# 2  1896       Greece  GER      Germany     7       5       2      14
# 3  1896       Greece  FRA       France     5       4       2      11
# 4  1896       Greece  GBR           UK     3       3       3       9
# 5  1896       Greece  DEN      Denmark     1       2       3       6
# 6  1896       Greece  HUN      Hungary     2       1       3       6
# 7  1896       Greece  AUT      Austria     2       1       2       5
# 8  1896       Greece  AUS    Australia     2       0       1       3
# 9  1896       Greece  SUI  Switzerland     1       2       0       3

# %% [raw]
# medals_df.to_csv('Summer_Medal_Count.csv',index = False)

# %% [markdown]
# ### Merging Athlete_count & Medals_count
# ---

# %%
final_df = athlete_df.merge(medals_df, how='left').fillna(0)
final_df = final_df.sort_values(['Year','Medals','Country'], ascending = [True,False,True])

print(final_df.shape)
final_df.head(10)
# Out:
# (2810, 11)
#    Year Host_Country      Country  NOC  Athletes  Sports  Events  Gold  \
# 0  1896       Greece       Greece  GRE       102       9      39  10.0
# 2  1896       Greece          USA  USA        14       3      16  11.0
# 1  1896       Greece      Germany  GER        19       6      27   7.0
# 3  1896       Greece       France  FRA        12       6      18   5.0
# 4  1896       Greece           UK  GBR        10       7      19   3.0
# 7  1896       Greece      Denmark  DEN         3       5      12   1.0
# 5  1896       Greece      Hungary  HUN         7       6      14   2.0
# 6  1896       Greece      Austria  AUT         3       3       8   2.0
# 9  1896       Greece    Australia  AUS         1       2       5   2.0
# 8  1896       Greece  Switzerland  SUI         3       2       5   1.0
#
#    Silver  Bronze  Medals
# 0    17.0    17.0    44.0
# 2     6.0     2.0    19.0
# 1     5.0     2.0    14.0
# 3     4.0     2.0    11.0
# 4     3.0     3.0     9.0
# 7     2.0     3.0     6.0
# 5     1.0     3.0     6.0
# 6     1.0     2.0     5.0
# 9     0.0     1.0     3.0
# 8     2.0     0.0     3.0

# %%
final_df['Medals'] = final_df['Medals'].astype(int)

final_df['Gold'] = final_df['Gold'].astype(int)

final_df['Silver'] = final_df['Silver'].astype(int)

final_df['Bronze'] = final_df['Bronze'].astype(int)

print(final_df.shape)
final_df.head(10)
# Out:
# (2810, 11)
#    Year Host_Country      Country  NOC  Athletes  Sports  Events  Gold  \
# 0  1896       Greece       Greece  GRE       102       9      39    10
# 2  1896       Greece          USA  USA        14       3      16    11
# 1  1896       Greece      Germany  GER        19       6      27     7
# 3  1896       Greece       France  FRA        12       6      18     5
# 4  1896       Greece           UK  GBR        10       7      19     3
# 7  1896       Greece      Denmark  DEN         3       5      12     1
# 5  1896       Greece      Hungary  HUN         7       6      14     2
# 6  1896       Greece      Austria  AUT         3       3       8     2
# 9  1896       Greece    Australia  AUS         1       2       5     2
# 8  1896       Greece  Switzerland  SUI         3       2       5     1
#
#    Silver  Bronze  Medals
# 0      17      17      44
# 2       6       2      19
# 1       5       2      14
# 3       4       2      11
# 4       3       3       9
# 7       2       3       6
# 5       1       3       6
# 6       1       2       5
# 9       0       1       3
# 8       2       0       3

# %%
# final_df['Host'] = [1 if (final_df['Host'] == final_df['Host_Country'])  else 0 for cell in medals_df['Medals']]

final_df['Host'] = 0

final_df.loc[final_df['Country'] == final_df['Host_Country'], 'Host'] = 1

print(final_df.shape)
final_df.head(10)
# Out:
# (2810, 12)
#    Year Host_Country      Country  NOC  Athletes  Sports  Events  Gold  \
# 0  1896       Greece       Greece  GRE       102       9      39    10
# 2  1896       Greece          USA  USA        14       3      16    11
# 1  1896       Greece      Germany  GER        19       6      27     7
# 3  1896       Greece       France  FRA        12       6      18     5
# 4  1896       Greece           UK  GBR        10       7      19     3
# 7  1896       Greece      Denmark  DEN         3       5      12     1
# 5  1896       Greece      Hungary  HUN         7       6      14     2
# 6  1896       Greece      Austria  AUT         3       3       8     2
# 9  1896       Greece    Australia  AUS         1       2       5     2
# 8  1896       Greece  Switzerland  SUI         3       2       5     1
#
#    Silver  Bronze  Medals  Host
# 0      17      17      44     1
# 2       6       2      19     0
# 1       5       2      14     0
# 3       4       2      11     0
# 4       3       3       9     0
# 7       2       3       6     0
# 5       1       3       6     0
# 6       1       2       5     0
# 9       0       1       3     0
# 8       2       0       3     0

# %%
final_df = final_df[['Year', 'Country', 'Host', 'Athletes', 'Sports', 'Events', 'Gold', 'Silver', 'Bronze', 'Medals']]
print(final_df.shape)
final_df.head(10)
# Out:
# (2810, 10)
#    Year      Country  Host  Athletes  Sports  Events  Gold  Silver  Bronze  \
# 0  1896       Greece     1       102       9      39    10      17      17
# 2  1896          USA     0        14       3      16    11       6       2
# 1  1896      Germany     0        19       6      27     7       5       2
# 3  1896       France     0        12       6      18     5       4       2
# 4  1896           UK     0        10       7      19     3       3       3
# 7  1896      Denmark     0         3       5      12     1       2       3
# 5  1896      Hungary     0         7       6      14     2       1       3
# 6  1896      Austria     0         3       3       8     2       1       2
# 9  1896    Australia     0         1       2       5     2       0       1
# 8  1896  Switzerland     0         3       2       5     1       2       0
#
#    Medals
# 0      44
# 2      19
# 1      14
# 3      11
# 4       9
# 7       6
# 5       6
# 6       5
# 9       3
# 8       3

# %%
final_df.to_csv('summer_athlete_medals_count.csv',index = False)
